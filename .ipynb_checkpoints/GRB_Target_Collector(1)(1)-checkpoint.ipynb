# %% [markdown]
# This goal of this script is to find GRBs that line up with the TESS mission in the GCN circulars archive.

# %% [markdown]
# The observation should have occurred between the start of TESS observation - which would be 2018-07-25 according to the Tess data release notes - up to the current date.

# %% [markdown]
# Also all observations must be in the southern hemisphere, where sectors 1 - 13 are located.

# %% [markdown]
# Use swift data first, then other missions may be observed.

# %% [markdown]
# 1. Set start and end dates for targets being observed, in this case start is GRB180725 (if it exists).
# 2. Find GRBs associated with swift observations.
# 3. Open circular file. (Memory Mapping, load file into memory and read matching strings from there.)
# 4. Find RA and DEC coordinates, filter out positive DEC coordinates.
# 5. Return link, coordinates, and identifier.
# 6. Run RA and DEC through tesscut to determine which sectors observation overlaps with
# 7. Determine date difference between sector observation date and swift observation date.

# %%
import numpy as np
import astropy as ap
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import sys
from datetime import datetime
from dateutil.parser import parse

# %%
sys.setrecursionlimit(10000)

# Following takes NASA circular webpage and turns it 
# into a Beautiful Soup object that can be used to match certain requirements

circ_Arch = requests.get('https://gcn.gsfc.nasa.gov/gcn/gcn3_archive.html')
circ_soup = BeautifulSoup(circ_Arch.text, 'html.parser')

circ_soup.prettify

# Regular Expressions for categorizing the elements in the circular list
# id_re returns the GRB and its number.
# obs_desc returns the description of the observation
# sn_re returns the serial numbers of each circular.

swift_re = re.compile(r'.*Swift detection.*')
id_re = re.compile(r'\D\D\D \d\d\d\d\d\d\D:')
obs_desc = re.compile(r'Swift.*')
sn_re = re.compile(r'(\d\d\d\d\d)')

# The circulars are sectioned in an unordered list.
circ_list = circ_soup.find('ul')

#Each element in the unordered list contains a circular link, an identifier and what made the observation.
# Circ_text is each li element in a text format.
circ_text = circ_list.find_next('li').get_text()

swift_obs = swift_re.findall(circ_text)
print(circ_soup)
# Out:
# <html>
# <head><title>GCN Circulars Archive</title>
# <script id="_fed_an_ua_tag" language="javascript" src='[1]"https://dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=NASA&amp;subagency=GSFC"'></script>
# </head>
# <body>
# <h1>GCN Circulars Archive</h1>
# <hr/>
# <p>
# This page changes after each Circular submission,
# so hit the   <blink>&lt;reload&gt;</blink>   button NOW.
# <p>
# <font color="#ff0000">
# Posted 24 Feb 2020.<br/>
# <p>
# The normal A/B/C identification of today's GRBs were incorrectly labelled A,<br/>
# because of the sequence assigner being offline.<br/>
# The 8 circulars in question were manually corrected for the A/B/C indentification. <br/>
# <br/>
# <font color="#000000">
# <ol>
# <li><a href="#tc1">The Latest Circulars</a></li>
# <li><a href="#tc2">Older Circulars</a></li>
# <li><a href="#tc3">Tarfile of all Circulars</a></li>
# <li><a href="selected.html">Circulars grouped by GRB/transient </a> </li>
# </ol>
# <hr/>
# <p>
# This is the archive of the GCN Observation Report Circulars.
# <p>
# To learn more about the <a href="gcn3_circulars.html">GCN Circulars</a>
# and <a href="invitation.html#tc2">how to subscribe</a>.
#    and to <a href="unsubscribe.html">unsubscribe here.</a><br/>
# <p>
# <a name="tc1"></a>
# <hr/>
# <h3>(Listed in reverse serial number order -- newest first)</h3>
# <p>
# <ul>
# <!--
# -->
# <!--XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX-->
# <li><a href="gcn3/27261.gcn3">27261</a> GRB 200228C: Insight-HXMT/HE detection<br/>
# <li><a href="gcn3/27260.gcn3">27260</a> GRB 200228A: Fermi GBM observation<br/>
# <li><a href="gcn3/27259.gcn3">27259</a> GRB 200228A: Swift/BAT detection and arcminute localization from GUANO<br/>
# <li><a href="gcn3/27258.gcn3">27258</a> SUBJECT : LIGO/Virgo S200213t: No significant EM counterparts identified from continued GECKO observation of host galaxy candidates<br/>
# <li><a href="gcn3/27257.gcn3">27257</a> GRB 200227A: Mondy optical upper limit<br/>
# <li><a href="gcn3/27256.gcn3">27256</a> GRB 200228B: Enhanced Swift-XRT position<br/>
# <li><a href="gcn3/27255.gcn3">27255</a> Fermi-LAT Gamma-ray Observations of IceCube-200227A<br/>
# <li><a href="gcn3/27254.gcn3">27254</a> GRB 200228B: Swift detection of a burst<br/>
# <li><a href="gcn3/27253.gcn3">27253</a> GRB 200228B: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27252.gcn3">27252</a> Fermi trigger No 604565918: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27251.gcn3">27251</a> GRB 200227A: Insight-HXMT/HE detection<br/>
# <li><a href="gcn3/27250.gcn3">27250</a> IceCube-200227A : Upper limits from Insight-HXMT/HE observations<br/>
# <li><a href="gcn3/27249.gcn3">27249</a> GRB 200227A: Swift-XRT refined Analysis<br/>
# <li><a href="gcn3/27248.gcn3">27248</a> GRB 200228A: BALROG localization (Fermi Trigger 604565918 / GRB 200228291)<br/>
# <li><a href="gcn3/27247.gcn3">27247</a> GRB 200228A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27246.gcn3">27246</a> GRB 200227A: Swift-BAT refined analysis<br/>
# <li><a href="gcn3/27245.gcn3">27245</a> GRB 200219A: ATCA 5/9 GHz radio observations<br/>
# <li><a href="gcn3/27244.gcn3">27244</a> GRB 200227A: Swift/UVOT Upper Limits<br/>
# <li><a href="gcn3/27243.gcn3">27243</a> GRB 200227A: Enhanced Swift-XRT position<br/>
# <li><a href="gcn3/27242.gcn3">27242</a> HAWC-200216A: No Neutrino Counterpart in ANTARES Search<br/>
# <li><a href="gcn3/27241.gcn3">27241</a> IceCube-200227A: Upper limits from Fermi-GBM Observations<br/>
# <li><a href="gcn3/27240.gcn3">27240</a> GRB 200224A: Mondy optical upper limit<br/>
# <li><a href="gcn3/27239.gcn3">27239</a> GRB 200227A: Fermi GBM observation<br/>
# <li><a href="gcn3/27238.gcn3">27238</a> LIGO/Virgo S200224ca : No significant candidates in TAROT - FRAM - GRANDMA observations<br/>
# <li><a href="gcn3/27237.gcn3">27237</a> IceCube-200227A: No counterpart candidates in INTEGRAL SPI-ACS and IBIS prompt observation<br/>
# <li><a href="gcn3/27236.gcn3">27236</a> GRB 200227A: MITSuME Akeno optical upper limit<br/>
# <li><a href="gcn3/27235.gcn3">27235</a> IceCube-200227A: IceCube observation of a high-energy neutrino candidate event<br/>
# <li><a href="gcn3/27234.gcn3">27234</a> GRB 200227A: Swift detection of a burst<br/>
# <li><a href="gcn3/27233.gcn3">27233</a> GRB 200227A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27232.gcn3">27232</a> LIGO/Virgo S200225q: Not observable by CALET<br/>
# <li><a href="gcn3/27231.gcn3">27231</a> LIGO/Virgo S200224ca: Upper limits from CALET observations.<br/>
# <li><a href="gcn3/27230.gcn3">27230</a> LIGO/Virgo S200224car: GRAWITA VST-ESO PARANAL observations.<br/>
# <li><a href="gcn3/27229.gcn3">27229</a> LIGO/Virgo S200225q: Updated Sky Localization<br/>
# <li><a href="gcn3/27228.gcn3">27228</a> Konus-Wind observation of GRB 200219C<br/>
# <li><a href="gcn3/27227.gcn3">27227</a> LIGO/Virgo S200224ca: DESGW Optical counterpart candidates from DECam<br/>
# <li><a href="gcn3/27226.gcn3">27226</a> Konus-Wind observation of GRB 200219A<br/>
# <li><a href="gcn3/27225.gcn3">27225</a> LIGO/Virgo S200219ac: Upper limits from Konus-Wind observations<br/>
# <li><a href="gcn3/27224.gcn3">27224</a> LIGO/Virgo S200213t: Upper limits from Konus-Wind observations<br/>
# <li><a href="gcn3/27223.gcn3">27223</a> LIGO/Virgo S200208q: Upper limits from Konus-Wind observations<br/>
# <li><a href="gcn3/27222.gcn3">27222</a> GRB 200224A: Calar Alto 2.2m optical afterglow detection<br/>
# <li><a href="gcn3/27221.gcn3">27221</a> LIGO/Virgo S200225q: no counterpart candidate in SVOM/GWAC observations<br/>
# <li><a href="gcn3/27220.gcn3">27220</a> LIGO/Virgo S200225q: Upper limits from Insight-HXMT/HE observations<br/>
# <li><a href="gcn3/27219.gcn3">27219</a> LIGO/Virgo S200224ca: Upper limits from Insight-HXMT/HE observations<br/>
# <li><a href="gcn3/27218.gcn3">27218</a> GRB 200219A: Chandra rapid ToO upper limit<br/>
# <li><a href="gcn3/27217.gcn3">27217</a> LIGO/Virgo S200225q: no counterpart candidates in the Swift/BAT observations<br/>
# <li><a href="gcn3/27216.gcn3">27216</a> LIGO/Virgo S200224ca: no counterpart candidates in the Swift/BAT observations<br/>
# <li><a href="gcn3/27215.gcn3">27215</a> GRB 200224B: DDOTI/OAN optical observations report<br/>
# <li><a href="gcn3/27214.gcn3">27214</a> LIGO/Virgo S200219ac: Updated Sky Localization<br/>
# <li><a href="gcn3/27213.gcn3">27213</a> LIGO/Virgo S200224ca: No counterpart candidates in KAIT observations<br/>
# <li><a href="gcn3/27212.gcn3">27212</a> LIGO/Virgo S200224ca: No Counterparts in DDOTI/OAN Optical Observations<br/>
# <li><a href="gcn3/27211.gcn3">27211</a> LIGO/Virgo S200224ca: GRAWITA-Campo Imperatore observations.<br/>
# <li><a href="gcn3/27210.gcn3">27210</a> IPN triangulation of GRB 200221A (short)<br/>
# <li><a href="gcn3/27209.gcn3">27209</a> LIGO/Virgo S200225q: Upper limits from Fermi-GBM Observations<br/>
# <li><a href="gcn3/27208.gcn3">27208</a> Fermi trigger No 604231129: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27207.gcn3">27207</a> LIGO/Virgo S200225q: No counterpart candidates in Fermi-LAT observations<br/>
# <li><a href="gcn3/27206.gcn3">27206</a> LIGO/Virgo S200225q: upper limits from AGILE/GRID observations<br/>
# <li><a href="gcn3/27205.gcn3">27205</a> LIGO/Virgo S200224ca: Subaru/Hyper Suprime-Cam follow-up observations<br/>
# <li><a href="gcn3/27204.gcn3">27204</a> LIGO/Virgo S200225q: upper limits from AGILE/MCAL observations<br/>
# <li><a href="gcn3/27203.gcn3">27203</a> LIGO/Virgo S200225q: Upper limits from IceCube neutrino searches<br/>
# <li><a href="gcn3/27202.gcn3">27202</a> LIGO/Virgo S200225q: No counterpart candidates in HAWC observations<br/>
# <li><a href="gcn3/27201.gcn3">27201</a> LIGO/Virgo S200225q : no neutrino counterpart candidate in ANTARES search<br/>
# <li><a href="gcn3/27200.gcn3">27200</a> LIGO/Virgo S200225q: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27199.gcn3">27199</a> LIGO/Virgo S200224ca: No counterpart candidates in Fermi-LAT observations<br/>
# <li><a href="gcn3/27198.gcn3">27198</a> LIGO/Virgo S200225q: No counterpart candidates in INTEGRAL SPI-ACS and IBIS prompt observation<br/>
# <li><a href="gcn3/27197.gcn3">27197</a> LIGO/Virgo S200225q: Coverage and upper limits from MAXI/GSC observations<br/>
# <li><a href="gcn3/27196.gcn3">27196</a> LIGO/Virgo S200219ac: No counterpart candidates from Nanshan/NEXT observations<br/>
# <li><a href="gcn3/27195.gcn3">27195</a> LIGO/Virgo S200224ca: upper limits from AGILE/GRID observations<br/>
# <li><a href="gcn3/27194.gcn3">27194</a> GRB 200224A: Swift-BAT refined analysis<br/>
# <li><a href="gcn3/27193.gcn3">27193</a> LIGO/Virgo S200225q: Identification of a GW compact binary merger candidate The LIGO Scientific Collaboration and the Virgo Collaboration<br/>
# <li><a href="gcn3/27192.gcn3">27192</a> LIGO/Virgo S200224ca: not observable by Fermi-GBM<br/>
# <li><a href="gcn3/27191.gcn3">27191</a> GRB 200224A: LCO Upper Limits<br/>
# <li><a href="gcn3/27190.gcn3">27190</a> LIGO/Virgo S200224ca: No counterpart candidates in INTEGRAL SPI-ACS prompt observation<br/>
# <li><a href="gcn3/27188.gcn3">27188</a> LIGO/Virgo S200224ca: Coverage and upper limits from MAXI/GSC observations<br/>
# <li><a href="gcn3/27187.gcn3">27187</a> LIGO/Virgo S200224ca: upper limits from AGILE/MCAL observations<br/>
# <li><a href="gcn3/27186.gcn3">27186</a> LIGO/Virgo S200224ca: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27185.gcn3">27185</a> LIGO/Virgo S200224ca: Upper limits from IceCube neutrino searches<br/>
# <li><a href="gcn3/27184.gcn3">27184</a> LIGO/Virgo S200224ca: Identification of a GW compact binary merger candidate The LIGO Scientific Collaboration and the Virgo Collaboration<br/>
# <li><a href="gcn3/27183.gcn3">27183</a> IPN triangulation of GRB 200224C<br/>
# <li><a href="gcn3/27182.gcn3">27182</a> GRB 200224A: Swift/UVOT Detection<br/>
# <li><a href="gcn3/27181.gcn3">27181</a> Correction in name: GRB 200224B and GRB 200224C (not GRB 200224A)<br/>
# <li><a href="gcn3/27180.gcn3">27180</a> GRB 200219C: Swift-XRT afterglow confirmation<br/>
# <li><a href="gcn3/27179.gcn3">27179</a> GRB 200224A: Swift-XRT refined Analysis<br/>
# <li><a href="gcn3/27178.gcn3">27178</a> GRB 200224C: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27177.gcn3">27177</a> GRB 200224A: Tautenburg observations<br/>
# <li><a href="gcn3/27176.gcn3">27176</a> GRB 200224A: BOOTES-1 and 1.5m OSN optical observations<br/>
# <li><a href="gcn3/27175.gcn3">27175</a> Fermi trigger No 604213554: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27174.gcn3">27174</a> GRB 200224B: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27173.gcn3">27173</a> GRB 200224A: Swift detection of a burst<br/>
# <li><a href="gcn3/27172.gcn3">27172</a> Swift GRB200224.14: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27171.gcn3">27171</a> GRB 200223A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27170.gcn3">27170</a> LIGO/Virgo S200219ac: no counterpart candidate in SVOM/GWAC-F30 observations<br/>
# <li><a href="gcn3/27169.gcn3">27169</a> LIGO/Virgo S200219ac: no counterpart candidate in SVOM/GWAC observations<br/>
# <li><a href="gcn3/27168.gcn3">27168</a> LIGO/Virgo S200219ac : No significant candidates in TAROT - FRAM - GRANDMA observations.<br/>
# <li><a href="gcn3/27167.gcn3">27167</a> IPN triangulation of GRB 200219B (inconsistent with the LIGO/Virgo S200219ac)<br/>
# <li><a href="gcn3/27166.gcn3">27166</a> GRB 200219C: OAJ afterglow confirmation<br/>
# <li><a href="gcn3/27165.gcn3">27165</a> GRB 200219A: UVOT Upper Limits<br/>
# <li><a href="gcn3/27164.gcn3">27164</a> GRB 200219A: FRAM-Auger optical limit<br/>
# <li><a href="gcn3/27163.gcn3">27163</a> GRB 200219C: CALET Gamma-Ray Burst Monitor detection<br/>
# <li><a href="gcn3/27162.gcn3">27162</a> GRB 200219Ð¡: Mondy and TSHAO optical observations<br/>
# <li><a href="gcn3/27161.gcn3">27161</a> GRB 200219C: Nanshan/NEXT optical upper limit and possible host galaxy from PanSTARRS<br/>
# <li><a href="gcn3/27160.gcn3">27160</a> LIGO/Virgo S200219ac: No counterpart candidates in KAIT observations<br/>
# <li><a href="gcn3/27159.gcn3">27159</a> GRB 200221A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27158.gcn3">27158</a> Fermi trigger No 603949983: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27157.gcn3">27157</a> GRB 200219C: Swift-XRT afterglow detection<br/>
# <li><a href="gcn3/27156.gcn3">27156</a> GRB 200219C: DDOTI Observations<br/>
# <li><a href="gcn3/27155.gcn3">27155</a> GRB 200219C: Fermi GBM detection<br/>
# <li><a href="gcn3/27154.gcn3">27154</a> LIGO/Virgo S200213t: AT2020clw/ZTF20aanaoyz, AT2020crd/ZTF20aanakge and AT2020cly/ZTF20aanakes 10.4m GTC spectroscopy<br/>
# <li><a href="gcn3/27153.gcn3">27153</a> LIGO/Virgo S200213t: Swift UVOT and XRT observations of ZTF20aamvmzj (AT2020cja)<br/>
# <li><a href="gcn3/27152.gcn3">27152</a> GRB 200219C: Tiled Swift observations<br/>
# <li><a href="gcn3/27151.gcn3">27151</a> GRB 200219C: Fermi-LAT detection<br/>
# <li><a href="gcn3/27150.gcn3">27150</a> GRB 200215A: LCO Optical Upper Limits<br/>
# <li><a href="gcn3/27149.gcn3">27149</a> LIGO/Virgo S200219ac: No transient candidates in CALET observations<br/>
# <li><a href="gcn3/27148.gcn3">27148</a> GRB 200219A, Swift-BAT refined analysis<br/>
# <li><a href="gcn3/27147.gcn3">27147</a> LIGO/Virgo S200219ac: no counterpart candidates in the Swift/BAT observations<br/>
# <li><a href="gcn3/27146.gcn3">27146</a> Fermi trigger No 603849435: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27145.gcn3">27145</a> GRB 200219C: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27144.gcn3">27144</a> LIGO/Virgo S200219ac: Fermi GBM transient event not confidently associated with GW signal<br/>
# <li><a href="gcn3/27143.gcn3">27143</a> LIGO/Virgo S200219ac: No counterpart candidates in Fermi-LAT observations<br/>
# <li><a href="gcn3/27142.gcn3">27142</a> GRB 200219A: Swift-XRT refined Analysis correction<br/>
# <li><a href="gcn3/27141.gcn3">27141</a> LIGO/Virgo S200219ac: upper limits from AGILE/GRID observations<br/>
# <li><a href="gcn3/27140.gcn3">27140</a> LIGO/Virgo S200213t: Keck/LRIS spectroscopy of counterpart candidates from the Zwicky Transient Facility<br/>
# <li><a href="gcn3/27139.gcn3">27139</a> GRB 200219A: Swift-XRT refined Analysis<br/>
# <li><a href="gcn3/27138.gcn3">27138</a> GRB 200219A: Enhanced Swift-XRT position<br/>
# <li><a href="gcn3/27137.gcn3">27137</a> GRB 200219A: Fermi GBM observation<br/>
# <li><a href="gcn3/27136.gcn3">27136</a> LIGO/Virgo S200219ac: upper limits from AGILE/MCAL observations<br/>
# <li><a href="gcn3/27135.gcn3">27135</a> LIGO/Virgo S200219ac : no neutrino counterpart candidate in ANTARES search<br/>
# <li><a href="gcn3/27134.gcn3">27134</a> LIGO/Virgo S200219ac: Upper limits from IceCube neutrino searches<br/>
# <li><a href="gcn3/27133.gcn3">27133</a> LIGO/Virgo S200219ac: No counterpart candidates in HAWC observations<br/>
# <li><a href="gcn3/27132.gcn3">27132</a> LIGO/Virgo S200219ac: Coverage and upper limits from MAXI/GSC observations<br/>
# <li><a href="gcn3/27131.gcn3">27131</a> LIGO/Virgo S200219ac: No counterpart candidates in INTEGRAL SPI-ACS and IBIS prompt observation<br/>
# <li><a href="gcn3/27130.gcn3">27130</a> LIGO/Virgo S200219ac: Identification of a GW compact binary merger candidate<br/>
# <li><a href="gcn3/27129.gcn3">27129</a> LIGO/Virgo S200219ac: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27128.gcn3">27128</a> GRB 200216B: second epoch optical upper limit at Mondy observatory<br/>
# <li><a href="gcn3/27127.gcn3">27127</a> GRB 200219B: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27126.gcn3">27126</a> GRB 200219A: MASTER catalog automatic possible Host Galaxy candidate<br/>
# <li><a href="gcn3/27125.gcn3">27125</a> GRB 200219A: Swift detection of a short burst<br/>
# <li><a href="gcn3/27124.gcn3">27124</a> Swift GRB200219.32: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27123.gcn3">27123</a> GRB 200219A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27122.gcn3">27122</a> GRB 200216B: Mondy and AbAO optical upper limits<br/>
# <li><a href="gcn3/27121.gcn3">27121</a> LIGO/Virgo (S200213t/IceCube neutrino candidate: No counterpart candidates in the Swift-XRT Observations<br/>
# <li><a href="gcn3/27120.gcn3">27120</a> GRB 200216B: Swift-XRT refined Analysis<br/>
# <li><a href="gcn3/27119.gcn3">27119</a> LIGO/Virgo S200213t: No EM counterparts found from continued GECKO observation of host galaxy candidates<br/>
# <li><a href="gcn3/27118.gcn3">27118</a> LIGO/Virgo S200213t: APO Upper Limits for ZTF20aanakes/AT2020cly<br/>
# <li><a href="gcn3/27117.gcn3">27117</a> GRB 200216B: Swift-BAT refined analysis<br/>
# <li><a href="gcn3/27116.gcn3">27116</a> LIGO/Virgo S200213t : No significant candidates in FRAM - OAJ - TAROT - GRANDMA observations<br/>
# <li><a href="gcn3/27115.gcn3">27115</a> Further Swift-XRT observations of Swift J0840.7-3516<br/>
# <li><a href="gcn3/27114.gcn3">27114</a> GRB 200216B - possible IR counterpart from VLT<br/>
# <li><a href="gcn3/27113.gcn3">27113</a> GRB 200215A: CALET Gamma-Ray Burst Monitor detection<br/>
# <li><a href="gcn3/27112.gcn3">27112</a> GRB 200216A: Fermi GBM detection<br/>
# <li><a href="gcn3/27111.gcn3">27111</a> LIGO/Virgo S200213t: AstroSat CZTI upper limits<br/>
# <li><a href="gcn3/27110.gcn3">27110</a> GRB 200216B: z-band limit from NOT<br/>
# <li><a href="gcn3/27109.gcn3">27109</a> GRB 200216B: Fermi GBM observation<br/>
# <li><a href="gcn3/27108.gcn3">27108</a> GRB 200216B: Swift/UVOT Upper Limits<br/>
# <li><a href="gcn3/27107.gcn3">27107</a> GRB 200216A: Swift/BAT detection and arcminute localization from GUANO<br/>
# <li><a href="gcn3/27106.gcn3">27106</a> GRB 200216B: Enhanced Swift-XRT position<br/>
# <li><a href="gcn3/27105.gcn3">27105</a> GRB 200215A: RATIR Optical Observations<br/>
# <li><a href="gcn3/27104.gcn3">27104</a> GRB 200216B: Nanshan/NEXT early optical upper limit and possible host galaxy<br/>
# <li><a href="gcn3/27103.gcn3">27103</a> GRB 200216B: GMG upper limit<br/>
# <li><a href="gcn3/27102.gcn3">27102</a> GRB 200216B: Swift detection of a burst<br/>
# <li><a href="gcn3/27101.gcn3">27101</a> GRB 200216B: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27100.gcn3">27100</a> Swift GRB200216.56: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27099.gcn3">27099</a> GRB 200215A: UKIRT H-band observations<br/>
# <li><a href="gcn3/27098.gcn3">27098</a> GRB 200215A: Swift-BAT refined analysis<br/>
# <li><a href="gcn3/27097.gcn3">27097</a> GRB 200216A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27096.gcn3">27096</a> LIGO/Virgo S200213t: Updated Sky Localization<br/>
# <li><a href="gcn3/27095.gcn3">27095</a> LIGO/Virgo S200213t: Updated coverage and candidate list for the Zwicky Transient Facility<br/>
# <li><a href="gcn3/27094.gcn3">27094</a> LIGO/Virgo S200213t: CLU/NED Galaxies in the 4-Update Localization Volume<br/>
# <li><a href="gcn3/27093.gcn3">27093</a> LIGO/Virgo S200213t: Possible host galaxies in the bilby skymap<br/>
# <li><a href="gcn3/27092.gcn3">27092</a> LIGO/Virgo S200213t: Updated Sky Localization<br/>
# <li><a href="gcn3/27091.gcn3">27091</a> GRB 200215A: Swift-XRT refined Analysis<br/>
# <li><a href="gcn3/27090.gcn3">27090</a> GRB 200215A: Swift/UVOT Upper Limits<br/>
# <li><a href="gcn3/27089.gcn3">27089</a> GRB 200215A: Enhanced Swift-XRT position<br/>
# <li><a href="gcn3/27088.gcn3">27088</a> GRB 200215A: Optical observations form Calar Alto 2.2m<br/>
# <li><a href="gcn3/27087.gcn3">27087</a> GRB 200215A: Fermi GBM detection<br/>
# <li><a href="gcn3/27086.gcn3">27086</a> GRB 200215A: Liverpool Telescope upper limits<br/>
# <li><a href="gcn3/27085.gcn3">27085</a> LIGO/Virgo S200213t: Pre-discovery detections of MASTER OT J044008.76-651302.3<br/>
# <li><a href="gcn3/27084.gcn3">27084</a> LIGO/Virgo S200213t: No transient candidates in CALET observations<br/>
# <li><a href="gcn3/27083.gcn3">27083</a> GRB 200215A Possible host galaxy in PanSTARRS<br/>
# <li><a href="gcn3/27082.gcn3">27082</a> LIGO/Virgo S200213t: Lulin Follow-Up Observations<br/>
# <li><a href="gcn3/27081.gcn3">27081</a> GRB 200215A: Nanshan/NEXT optical upper limit<br/>
# <li><a href="gcn3/27080.gcn3">27080</a> Swift GRB200215.61: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/
# <li><a href="gcn3/27057.gcn3">27057</a> LIGO/Virgo S191213g: AT2019wxt Wendelstein optical observations<br/>
# <li><a href="gcn3/27056.gcn3">27056</a> LIGO/Virgo S200213t: not observable by Fermi-GBM<br/>
# <li><a href="gcn3/27055.gcn3">27055</a> LIGO/Virgo S200213t: upper limits from AGILE/GRID observations<br/>
# <li><a href="gcn3/27054.gcn3">27054</a> LIGO/Virgo S200208q : No significant candidates in TAROT - FRAM - GRANDMA observations<br/>
# <li><a href="gcn3/27053.gcn3">27053</a> LIGO/Virgo S200208q: no counterpart candidate in SVOM/C-GFT observations<br/>
# <li><a href="gcn3/27052.gcn3">27052</a> LIGO/VIRGO S200213t: upper limits from AGILE/MCAL observations<br/>
# <li><a href="gcn3/27051.gcn3">27051</a> LIGO/Virgo S200213t: Candidates from the Zwicky Transient Facility<br/>
# <li><a href="gcn3/27050.gcn3">27050</a> LIGO/Virgo S200213t: No counterpart candidates in INTEGRAL SPI-ACS prompt observation<br/>
# <li><a href="gcn3/27049.gcn3">27049</a> LIGO/Virgo S200213t : no neutrino counterpart candidate in ANTARES search<br/>
# <li><a href="gcn3/27048.gcn3">27048</a> LIGO/Virgo S200213t: Coverage and upper limits from MAXI/GSC observations<br/>
# <li><a href="gcn3/27047.gcn3">27047</a> LIGO/Virgo S200213t: Neutrino and galaxies cross-match<br/>
# <li><a href="gcn3/27046.gcn3">27046</a> GRB 2002011A: AstroSat CZTI detection<br/>
# <li><a href="gcn3/27045.gcn3">27045</a> LIGO/Virgo trigger S200213t: Possible host galaxies<br/>
# <li><a href="gcn3/27044.gcn3">27044</a> LIGO/Virgo S200213t: NED Galaxies in the 90% Localization Volume<br/>
# <li><a href="gcn3/27043.gcn3">27043</a> LIGO/Virgo S200213t: 1 counterpart neutrino candidate from IceCube neutrino searches<br/>
# <li><a href="gcn3/27042.gcn3">27042</a> LIGO/Virgo S200213t: Identification of a GW compact binary merger candidate<br/>
# <li><a href="gcn3/27041.gcn3">27041</a> LIGO/Virgo S200213t: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27040.gcn3">27040</a> GRB 200212A: Fermi GBM Final Localization Correction<br/>
# <li><a href="gcn3/27039.gcn3">27039</a> ZTF20aajnksq: Upper limits from Konus-Wind observations<br/>
# <li><a href="gcn3/27038.gcn3">27038</a> Fermi trigger No 603197394: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27037.gcn3">27037</a> GRB 200212A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27036.gcn3">27036</a> LIGO/Virgo S200208q: Updated Sky Localization<br/>
# <li><a href="gcn3/27035.gcn3">27035</a> GRB 200131A: Tautenburg observations<br/>
# <li><a href="gcn3/27034.gcn3">27034</a> Konus-Wind observation of GRB 200205B<br/>
# <li><a href="gcn3/27033.gcn3">27033</a> LIGO/Virgo S200208q: No counterpart candidates in KAIT observations<br/>
# <li><a href="gcn3/27032.gcn3">27032</a> GRB 200211A: BALROG localization (Fermi Trigger 603098793 / GRB 200211310)<br/>
# <li><a href="gcn3/27031.gcn3">27031</a> GRB 200211A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27030.gcn3">27030</a> LIGO/Virgo S200208q: Not observable by CALET<br/>
# <li><a href="gcn3/27029.gcn3">27029</a> GRB 200207A: AstroSat CZTI detection<br/>
# <li><a href="gcn3/27028.gcn3">27028</a> LIGO/Virgo S200208q: No counterpart candidates in Fermi-LAT observations<br/>
# <li><a href="gcn3/27027.gcn3">27027</a> GRB 200205B: Chilescope optical observations<br/>
# <li><a href="gcn3/27026.gcn3">27026</a> LIGO/Virgo S200129m: Upper limits from Insight-HXMT/HE observations<br/>
# <li><a href="gcn3/27025.gcn3">27025</a> GRB 200120A: Fermi GBM observation<br/>
# <li><a href="gcn3/27024.gcn3">27024</a> LIGO/Virgo S200208q: Coverage and upper limits from MAXI/GSC observations<br/>
# <li><a href="gcn3/27023.gcn3">27023</a> LIGO/Virgo S200208q: no counterpart candidates in the Swift/BAT observations<br/>
# <li><a href="gcn3/27022.gcn3">27022</a> LIGO/Virgo S200208q: Upper limits from Fermi-GBM Observations<br/>
# <li><a href="gcn3/27021.gcn3">27021</a> LIGO/Virgo S200208q : upper limits from AGILE/GRID observations<br/>
# <li><a href="gcn3/27020.gcn3">27020</a> LIGO/Virgo S200208q: upper limits from AGILE/MCAL observations<br/>
# <li><a href="gcn3/27019.gcn3">27019</a> LIGO/Virgo S200208q: No counterpart candidates in INTEGRAL SPI-ACS prompt observation<br/>
# <li><a href="gcn3/27018.gcn3">27018</a> LIGO/Virgo S200208q: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27017.gcn3">27017</a> LIGO/Virgo S200208q: No counterpart candidates in HAWC observations<br/>
# <li><a href="gcn3/27016.gcn3">27016</a> LIGO/Virgo S200208q : no neutrino counterpart candidate in ANTARES search<br/>
# <li><a href="gcn3/27015.gcn3">27015</a> LIGO/Virgo S200208q: Upper limits from IceCube neutrino searches<br/>
# <li><a href="gcn3/27014.gcn3">27014</a> LIGO/Virgo S200208q: Identification of a GW compact binary merger candidate<br/>
# <li><a href="gcn3/27013.gcn3">27013</a> Fermi trigger No 602817262: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27012.gcn3">27012</a> GRB 200205B: Swift-BAT refined analysis<br/>
# <li><a href="gcn3/27011.gcn3">27011</a> GRB 200208A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27010.gcn3">27010</a> Swift J0840.7-3516 (AKA GRB 200205A): Swift-BAT refined analysis<br/>
# <li><a href="gcn3/27009.gcn3">27009</a> Fermi trigger No 602731380: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27008.gcn3">27008</a> Swift Trigger 954840 is not a GRB<br/>
# <li><a href="gcn3/27007.gcn3">27007</a> Swift GRB200207.13: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/27006.gcn3">27006</a> GRB 200205B: Swift/UVOT Detection<br/>
# <li><a href="gcn3/27005.gcn3">27005</a> GRB 200207A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27004.gcn3">27004</a> GRB 200205B: ESO/NTT near-infrared imaging<br/>
# <li><a href="gcn3/27003.gcn3">27003</a> GRB 200205A = Swift J0840.7-3516: optical photometry in Chilescope observatory<br/>
# <li><a href="gcn3/27002.gcn3">27002</a> GRB 200206A: Fermi GBM Final Real-time Localization<br/>
# <li><a href="gcn3/27001.gcn3">27001</a> GRB 200205B: Swift-XRT refined Analysis<br/>
# <li><a href="gcn3/27000.gcn3">27000</a> GRB 200205A = Swift J0840.7-3516, A newly discovered transient X-ray Pulsar<br/>
# <li><a href="gcn3/26999.gcn3">26999</a> GRB 200205B: Enhanced Swift-XRT position<br/>
# <li><a href="gcn3/26998.gcn3">26998</a> GRB 200205B: VLT/X-shooter redshift<br/>
# <li><a href="gcn3/26997.gcn3">26997</a> Fermi trigger No 602626648: Global MASTER-Net observations report<br/>
# <li><a href="gcn3/26996.gcn3">26996</a> GRB 200205A: Enhanced Swift-XRT position<br/>
# <li><a href="gcn3
# <a href="gcn3_arch_old12.html">Circulars 1100-1199   01-09-22 to 01-12-13</a><br/>
# <a href="gcn3_arch_old11.html">Circulars 1000-1099   01-03-02 to 01-09-22</a><br/>
# <a href="gcn3_arch_old10.html">Circulars 900-999   00-12-14 to 01-03-01</a><br/>
# <a href="gcn3_arch_old9.html">Circulars 800-899   00-09-27 to 00-12-14</a><br/>
# <a href="gcn3_arch_old8.html">Circulars 700-799   00-06-13 to 00-09-27</a><br/>
# <a href="gcn3_arch_old7.html">Circulars 600-699   00-03-08 to 00-06-13</a><br/>
# <a href="gcn3_arch_old6.html">Circulars 500-599   99-12-16 to 00-03-08</a><br/>
# <a href="gcn3_arch_old5.html">Circulars 400-499   99-08-10 to 99-12-16</a><br/>
# <a href="gcn3_arch_old4.html">Circulars 300-399   99-05-08 to 99-08-10</a><br/>
# <a href="gcn3_arch_old3.html">Circulars 199-299   99-01-23 to 99-05-07</a><br/>
# <a href="gcn3_arch_old2.html">Circulars 100-198   98-06-13 to 99-01-22</a><br/>
# <a href="gcn3_arch_old1.html">Circulars neg4-099   97-02-?? to 98-06-13</a><br/>
# <p>
# <hr/>
# <a name="tc3"><b>Tarfile of all Circulars</b></a><br/>
# <p>
# <a href="gcn3/all_gcn_circulars.tar.gz">Tar file of all the circulars (as of a couple minutes after every midnight US EastCoast local time)</a>.<br/>
# This tarfile is a convenient way of getting all the Circulars if you want to 'mine' them for some particular need.<br/>
# (If you are willing to share, I would appreciate getting a copy (for my own private GCN_Administrater use)<br/>
#  of whatever statistical analyses you derive from your mining.)<br/>
# <p>
# <hr/>
# <!-- <b>Invitation to subscribe to the Circulars<a href="invitation.html"> here</a>.</b> &nbsp;&nbsp;&nbsp;<a href="unsubscribe.html">unsubscribe here.</a><br> -->
# <a href="gcn_main.html">Return to GCN/TAN homepage</a>.
# <hr/>
# <i>This file was last modified by a human on 27-Sep-19.</i>
# </p></p></p></p></p></p></p></p></p></p></font></p></font></p></p></body>
# </html>

# %%
# This cell produced a preliminary table. The proper data set is in the following cells

# This for loop creates a list of the grb identifiers that fall under the swift observations.
i = 0
grb_ids = []
desc_list = []
sn_list = []

#element is one line in the swift obs that contains the circular #, identifier and observation description
for element in swift_obs:
    grb_ID = id_re.findall(element)
    desc = obs_desc.findall(element)
    sn = sn_re.findall(element)
    # Some empty lists are in the original ul tag so these are skipped
    if len(grb_ID) == 0:
        continue
    else:
        grb_ids.append(grb_ID[0]) #Using index notation to append the string element instead of a list object.
        desc_list.append(desc[0])
        sn_list.append(sn[0])
print(len(sn_list))
# Out:
# 44

# %%
# The circular list is converted to a string and passed through the swift reg exp.
# Useful for navigating through desired swift ciculars, and extracting desired tags.
ul_array = swift_re.findall(str(circ_list))
# Regular expression for all href link names
gcn_re = re.compile(r'gcn3.*gcn3')

#Following code filters out the circular links from the tags, and puts them into a list.
href_list = []
for li in ul_array:
    gcn = gcn_re.findall(li)
    href_list.append(gcn[0])

# Every circular link has the following string preceding its circular number.
link = "https://gcn.gsfc.nasa.gov/"

#Each string in href_list is appended to link to create the full gcn link for the corresponding observation.
# These are then appended to link_list.
link_list = []
for circular in href_list:
    link_gcn = link + circular #Main link + corresponding circular string
    link_list.append(link_gcn)

# %%
gcn_text = []
#Each complete circular address in link_list is requested and converted into string format.
# These strings are then appended to a list, so that each circular can be parsed through
# to find coordinates and dates.
for gcn in link_list:
    link_src = requests.get(gcn)
    gcn_circ = link_src.text
    gcn_text.append(gcn_circ)

# %%
#Regular expressions for date, RA, DEC and identifiers
date_re = re.compile(r'\d\d.*GMT')
cord_re = re.compile(r'RA, Dec.*\d\d\d')


#Lists for each category
date_list = []
cord_list = []
id_list = []

for text in gcn_text:
    date = date_re.findall(text)
    cord = cord_re.findall(text)
    i_d = id_re.findall(text)
    
    # If else statement to overlook any empty lists, which will skip over duplicate identifiers.
    if len(i_d) == 0:
        continue
    else:
        date_list.append(date[0])
        cord_list.append(cord)
        id_list.append(i_d)
         
print(len(cord_list))
print(len(date_list))
print(len(id_list))
# Out:
# 44
# 44
# 44

# %%
# Creates a table from the lists made in the previous cell.
pd.DataFrame(list(zip(id_list, cord_list, date_list, link_list)), columns= ["ID", "RA, Dec", "Date", "Circular"])
# Out:
#                 ID                                            RA, Dec  \
# 0   [GRB 200224A:]  [RA, Dec 248.794, +41.675, RA, Dec 248.7668, 4...
# 1   [GRB 200219A:]                         [RA, Dec 342.644, -59.108]
# 2   [GRB 200216B:]                         [RA, Dec 160.461, +19.454]
# 3   [GRB 200215A:]         [RA, Dec 34.122, +12.781, RA, Dec 34.0794]
# 4   [GRB 200205B:]       [RA, Dec 107.861, -56.506, RA, Dec 107.7881]
# 5   [GRB 200205A:]  [RA, Dec 130.171, -35.245, RA, Dec 130.1717, -...
# 6   [GRB 200131A:]  [RA, Dec 3.095, +51.124, RA, Dec 3.0942, 51.1158]
# 7   [GRB 200127A:]      [RA, Dec 295.204, +44.910, RA, Dec 295.19447]
# 8   [GRB 200125A:]  [RA, Dec 228.047, -8.148, RA, Dec 228.0471, -8...
# 9   [GRB 200122A:]  [RA, Dec 209.981, +27.566, RA, Dec 210.01625, ...
# 10  [GRB 200115A:]                           [RA, Dec 56.454, +5.613]
# 11  [GRB 200109A:]                         [RA, Dec 307.171, +53.003]
# 12  [GRB 200107B:]  [RA, Dec 107.066, -83.716, RA, Dec 106.92567, ...
# 13  [GRB 191228A:]  [RA, Dec 5.339, -8.670, RA, Dec 5.34755, -8.68...
# 14  [GRB 191227A:]                         [RA, Dec 319.170, -16.704]
# 15  [GRB 191221B:]  [RA, Dec 154.832, -38.141, RA, Dec 154.8286, -...
# 16  [GRB 191220A:]      [RA, Dec 281.391, +26.667, RA, Dec 281.37924]
# 17  [GRB 191218A:]                         [RA, Dec 301.078, -40.274]
# 18  [GRB 191213A:]                          [RA, Dec 224.507, -9.726]
# 19  [GRB 191123A:]                         [RA, Dec 215.261, +22.842]
# 20  [GRB 191122A:]        [RA, Dec 54.296, -32.176, RA, Dec 54.26926]
# 21  [GRB 191106A:]       [RA, Dec 269.350, +46.052, RA, Dec 269.3349]
# 22  [GRB 191101A:]  [RA, Dec 251.844, +43.754, RA, Dec 251.83474, ...
# 43  19/07/18 04:51:09 GMT  https://gcn.gsfc.nasa.gov/gcn3/25368.gcn3

# %%
# Regular expression for parsing coordinates and their labels.
ra_exp = re.compile('RA')
dec_exp = re.compile('Dec')
cord_exp = re.compile(r'\-?\d?\d?\d.\d\d\d')

ra_list = []
dec_list = []

for cord in cord_list:
    ra_cord = cord_exp.findall(cord[0])[0] # First match in each coordinate element is ra
    dec_cord = cord_exp.findall(cord[0])[1]# Second match in each coordinate element is dec
    
    ra_list.append(ra_cord)
    dec_list.append(dec_cord)

# %%
# Results from tesscut api are appended to the following lists.
sec_list = []
sec_names = []
sec_cams = []
ccd_list = []


for i in range(0,44):
    payload = {'ra': ra_list[i], 'dec': dec_list[i], 'radius':'1m'}
    r = requests.get('https://mast.stsci.edu/tesscut/api/v0.1/sector', params = payload)
    
    #Result is a list and returns the values generated by the tesscut api.
    result = r.json()['results']
    
    # Certain coordinates do not return any sector results, filtered out and
    # A N/A value is returned to a list using an if else statement.
    
    if len(result) == 0:
        sec_list.append('N/A')
        sec_names.append('N/A')
        sec_cams.append('N/A')
        ccd_list.append('N/A')
    elif len(result) == 1:
        sec_list.append(result[0]['sector'])
        sec_names.append(result[0]['sectorName'])
        sec_cams.append(result[0]['camera'])
        ccd_list.append(result[0]['ccd'])
    else:
        sec_list.append(result[0]['sector'] + " " + result[1]['sector'])
        sec_names.append(result[0]['sectorName'] + " " + result[1]['sectorName'])
        sec_cams.append(result[0]['camera'] + " " + result[1]['camera'])
        ccd_list.append(result[0]['ccd'] + " " + result[1]['ccd'])

# %%
big_table = pd.DataFrame(list(zip(id_list, cord_list, date_list, link_list,sec_list, sec_names, sec_cams, ccd_list)), 
             columns= ["ID", "RA, Dec", "Swift Date", "Circular", "Sector", "SectorName", "Camera", "ccd"])
big_table
# Out:
#                 ID                                            RA, Dec  \
# 0   [GRB 200224A:]  [RA, Dec 248.794, +41.675, RA, Dec 248.7668, 4...
# 1   [GRB 200219A:]                         [RA, Dec 342.644, -59.108]
# 2   [GRB 200216B:]                         [RA, Dec 160.461, +19.454]
# 3   [GRB 200215A:]         [RA, Dec 34.122, +12.781, RA, Dec 34.0794]
# 4   [GRB 200205B:]       [RA, Dec 107.861, -56.506, RA, Dec 107.7881]
# 5   [GRB 200205A:]  [RA, Dec 130.171, -35.245, RA, Dec 130.1717, -...
# 6   [GRB 200131A:]  [RA, Dec 3.095, +51.124, RA, Dec 3.0942, 51.1158]
# 7   [GRB 200127A:]      [RA, Dec 295.204, +44.910, RA, Dec 295.19447]
# 8   [GRB 200125A:]  [RA, Dec 228.047, -8.148, RA, Dec 228.0471, -8...
# 9   [GRB 200122A:]  [RA, Dec 209.981, +27.566, RA, Dec 210.01625, ...
# 10  [GRB 200115A:]                           [RA, Dec 56.454, +5.613]
# 11  [GRB 200109A:]                         [RA, Dec 307.171, +53.003]
# 12  [GRB 200107B:]  [RA, Dec 107.066, -83.716, RA, Dec 106.92567, ...
# 13  [GRB 191228A:]  [RA, Dec 5.339, -8.670, RA, Dec 5.34755, -8.68...
# 14  [GRB 191227A:]                         [RA, Dec 319.170, -16.704]
# 15  [GRB 191221B:]  [RA, Dec 154.832, -38.141, RA, Dec 154.8286, -...
# 16  [GRB 191220A:]      [RA, Dec 281.391, +26.667, RA, Dec 281.37924]
# 17  [GRB 191218A:]                         [RA, Dec 301.078, -40.274]
# 18  [GRB 191213A:]                          [RA, Dec 224.507, -9.726]
# 19  [GRB 191123A:]                         [RA, Dec 215.261, +22.842]
# 20  [GRB 191122A:]        [RA, Dec 54.296, -32.176, RA, Dec 54.26926]
# 21  [GRB 191106A:]       [RA, Dec 269.350, +46.052, RA, Dec 269.3349]
# 22  [GRB 191101A:]  [RA, Dec 251.844, +43.754, RA, Dec 251.83474, ...
# 23  [GRB 191031D:]       [RA, Dec 283.275, +47.639, RA, Dec 283.2890]
# 24  [GRB 191031C:]  [RA, Dec 115.862, -62.335, RA, Dec 115.8682, -...
# 25  [GRB 191031A:]                          [RA, Dec 233.470, +6.144]
# 26  [GRB 191029A:]                         [RA, Dec 352.140, -40.464]
# 27  [GRB 191024A:]  [RA, Dec 10.147, -67.139, RA, Dec 10.11387, -6...
# 28  [GRB 191019A:]                         [RA, Dec 340.038, -17.333]
# 29  [GRB 191017B:]  [RA, Dec 245.151, -73.561, RA, Dec 245.1255, -...
# 30  [GRB 191016A:]                          [RA, Dec 30.296, +24.501]
# 31  [GRB 191011A:]  [RA, Dec 44.724, -27.845, RA, Dec 44.72679, -2...
# 32  [GRB 191004B:]  [RA, Dec 49.177, -39.613, RA, Dec 49.20403, -3...
# 33  [GRB 191004A:]  [RA, Dec 31.721, -36.932, RA, Dec 31.66950, -3...
# 34  [GRB 191001B:]                          [RA, Dec 86.368, -15.907]
# 35  [GRB 190926A:]  [RA, Dec 100.599, +59.511, RA, Dec 100.5699, 5...
# 36  [GRB 190829A:]          [RA, Dec 44.540, -8.968, RA, Dec 44.5440]
# 37  [GRB 190828B:]                          [RA, Dec 251.818, 27.237]
# 38  [GRB 190824A:]       [RA, Dec 215.329, -41.902, RA, Dec 215.3045]
# 39  [GRB 190821A:]  [RA, Dec 250.077, -34.022, RA, Dec 250.05464, ...
# 40  [GRB 190816A:]                         [RA, Dec 341.193, -29.740]
# 41  [GRB 190727B:]                         [RA, Dec 126.481, -13.268]
# 42  [GRB 190719C:]      [RA, Dec 240.210, +12.977, RA, Dec 240.20700]
# 43  [GRB 190718A:]  [RA, Dec 336.531, -41.221, RA, Dec 336.57614, ...
#
#                Swift Date                                   Circular  \
# 0   20/02/24 03:41:23 GMT  https://gcn.gsfc.nasa.gov/gcn3/27173.gcn3
# 1   20/02/19 07:55:10 GMT  https://gcn.gsfc.nasa.gov/gcn3/27125.gcn3
# 2   20/02/16 13:57:44 GMT  https://gcn.gsfc.nasa.gov/gcn3/27102.gcn3
# 3   20/02/15 15:14:13 GMT  https://gcn.gsfc.nasa.gov/gcn3/27079.gcn3
# 4   20/02/05 19:46:01 GMT  https://gcn.gsfc.nasa.gov/gcn3/26993.gcn3
# 42        N/A                            N/A    N/A  N/A
# 43       0001                 tess-s0001-1-2      1    2

# %%
# The list of sectors and their start and end dates are stored in the dictionary sec_date.
sec_date = {"Sec26" : ["2020-06-08", "2020-07-04"], "Sec25" : ["2020-05-13", "2020-06-08"], 
            "Sec24" : ["2020-04-16", "2020-05-13"], "Sec23" : ["2020-03-18", "2020-04-16"], 
            "Sec22" : ["2020-02-18", "2020-03-18"], "Sec21" : ["2020-01-21", "2020-02-18"], 
            "Sec20" : ["2019-12-24", "2020-01-21"], "Sec19" : ["2019-11-27", "2019-12-24"], 
            "Sec18" : ["2019-11-02", "2019-11-27"], "Sec17" : ["2019-10-07", "2019-11-02"], 
            "Sec16" : ["2019-09-11", "2019-10-07"], "Sec15" : ["2019-08-15", "2019-09-11"], 
            "Sec14" : ["2019-07-18", "2019-08-15"], "Sec13" : ["2019-06-19", "2019-07-18"], 
            "Sec12" : ["2019-05-21", "2019-06-19"], "Sec11" : ["2019-04-22", "2019-05-21"], 
            "Sec10" : ["2019-03-26", "2019-04-22"], "Sec9" : ["2019-02-28", "2019-03-25"], 
            "Sec8" : ["2019-02-02", "2019-02-27"], "Sec7" : ["2019-01-08", "2019-02-01"], 
            "Sec6" : ["2018-12-12", "2019-01-06"], "Sec5" : ["2018-11-15", "2018-12-11"], 
            "Sec4" : ["2018-10-19", "2018-11-14"], "Sec3" : ["2018-09-20", "2018-10-17"], 
            "Sec2" : ["2018-08-23", "2018-09-20"], "Sec1" : ["2018-07-25", "2018-08-22"]}

#Grabs the dates column from the big table.https://archive.stsci.edu/tess/tess_drn.html
swift_arr = big_table['Swift Date']

#List of tess sector dates as datetime objects.
# Each sector is in a list, containing its beg and end dates.
tess_dt = []

#Converts sec_date values to datetime objects
for dates in sorted(sec_date.values()):
    dates[0] = (datetime.strptime(dates[0], "%Y-%m-%d")) #sector beginning date
    dates[1] = (datetime.strptime(dates[1], "%Y-%m-%d")) #sector end date  
    tess_dt.append(dates)

# Loop chops off timezone for conversion to datetime object.
# Converted to new list and appended to swift_dt list.
swift_dt = []
for swift_date in swift_arr:
    swift_date = (datetime.strptime(swift_date[0:8], "%y/%m/%d"))
    swift_dt.append(swift_date)
print(tess_dt)
# Out:
# [[datetime.datetime(2018, 7, 25, 0, 0), datetime.datetime(2018, 8, 22, 0, 0)], [datetime.datetime(2018, 8, 23, 0, 0), datetime.datetime(2018, 9, 20, 0, 0)], [datetime.datetime(2018, 9, 20, 0, 0), datetime.datetime(2018, 10, 17, 0, 0)], [datetime.datetime(2018, 10, 19, 0, 0), datetime.datetime(2018, 11, 14, 0, 0)], [datetime.datetime(2018, 11, 15, 0, 0), datetime.datetime(2018, 12, 11, 0, 0)], [datetime.datetime(2018, 12, 12, 0, 0), datetime.datetime(2019, 1, 6, 0, 0)], [datetime.datetime(2019, 1, 8, 0, 0), datetime.datetime(2019, 2, 1, 0, 0)], [datetime.datetime(2019, 2, 2, 0, 0), datetime.datetime(2019, 2, 27, 0, 0)], [datetime.datetime(2019, 2, 28, 0, 0), datetime.datetime(2019, 3, 25, 0, 0)], [datetime.datetime(2019, 3, 26, 0, 0), datetime.datetime(2019, 4, 22, 0, 0)], [datetime.datetime(2019, 4, 22, 0, 0), datetime.datetime(2019, 5, 21, 0, 0)], [datetime.datetime(2019, 5, 21, 0, 0), datetime.datetime(2019, 6, 19, 0, 0)], [datetime.datetime(2019, 6, 19, 0, 0), datetime.datetime(2019, 7, 18, 0, 0)], [datetime.datetime(2019, 7, 18, 0, 0), datetime.datetime(2019, 8, 15, 0, 0)], [datetime.datetime(2019, 8, 15, 0, 0), datetime.datetime(2019, 9, 11, 0, 0)], [datetime.datetime(2019, 9, 11, 0, 0), datetime.datetime(2019, 10, 7, 0, 0)], [datetime.datetime(2019, 10, 7, 0, 0), datetime.datetime(2019, 11, 2, 0, 0)], [datetime.datetime(2019, 11, 2, 0, 0), datetime.datetime(2019, 11, 27, 0, 0)], [datetime.datetime(2019, 11, 27, 0, 0), datetime.datetime(2019, 12, 24, 0, 0)], [datetime.datetime(2019, 12, 24, 0, 0), datetime.datetime(2020, 1, 21, 0, 0)], [datetime.datetime(2020, 1, 21, 0, 0), datetime.datetime(2020, 2, 18, 0, 0)], [datetime.datetime(2020, 2, 18, 0, 0), datetime.datetime(2020, 3, 18, 0, 0)], [datetime.datetime(2020, 3, 18, 0, 0), datetime.datetime(2020, 4, 16, 0, 0)], [datetime.datetime(2020, 4, 16, 0, 0), datetime.datetime(2020, 5, 13, 0, 0)], [datetime.datetime(2020, 5, 13, 0, 0), datetime.datetime(2020, 6, 8, 0, 0)], [datetime.datetime(2020, 6, 8, 0, 0), datetime.datetime(2020, 7, 4, 0, 0)]]

# %%
# List grabs sectors from big_table - related sectors 
sectors = big_table['Sector']
# Convert sectors to integers, used to iterate through tess_dt dictionary by sector.
sec_ints = []
for sec in sectors:
    if sec[0] == '0':
        sec = int(sec[:4])
        sec_ints.append(sec)
    else:
        sec = sec[:4]
        sec_ints.append(sec)

# Iterate through the dates of the corresponding sectors of tess.
# Used to compare tess dates with swift dates.
rel_sec = []
for sec_num in sec_ints:
    if type(sec_num) == int:
        rel_sec.append(tess_dt[sec_num - 1])
        
    else:
        rel_sec.append("N/A")

# Swift count is used to iterate through swift_dt simultaneously with the rel_sec loop
# This is so the differences in dates can be appended to a list.
swift_count = 0

# List of tess start and end date differences
strt_diffs = []
end_diffs = []

for date in rel_sec:
    if len(date) == 2:
        start_diff = swift_dt[swift_count] - date[0] # Difference between swift observation and tess sector beg date
        end_diff = swift_dt[swift_count] - date[1] # "                                            " end date
        strt_diffs.append(start_diff)
        end_diffs.append(end_diff)
    else:
        strt_diffs.append("N/A")
        end_diffs.append("N/A")
    swift_count += 1
    
print(len(strt_diffs))
# Out:
# 44

# %%
bigger_table = pd.DataFrame(list(zip(id_list, cord_list, date_list, link_list,sec_list, sec_names, sec_cams, ccd_list,
                                    strt_diffs, end_diffs)), 
             columns= ["ID", "RA, Dec", "Swift Date", "Circular", "Sector", "SectorName", "Camera", "ccd", 
                       "Difference between TESS sector start date and Swift Obs Date", 
                       "Difference between TESS sector end date and Swift Obs Date"])
bigger_table.to_html("GRB_Table.html")
